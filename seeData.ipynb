# %%
import MiniProject as mp
import matplotlib.pyplot as plt

# mp.df['Categorie'].value_counts().plot(kind='line')
# plt.title('Répartition des catégories')
# plt.show()
mp.df
# Out:
#         Name  Age    Salary Department  Years_Experience Remote  \
# ID
# 1    Othmane   45  69930.00         IT                 0    Yes
# 2      Ikram   22  61659.73         HR                23    Yes
# 3        Bob   45  61659.73         HR                26    Yes
# 4      Zineb   59  73665.00         HR                 3     No
# 5      David   57  59325.00    Finance                33     No
# 6      Ikram   52  70395.15  Marketing                12     No
# 7      Zineb   56  70395.15  Marketing                10    Yes
# 8      Hamza   45  70395.15  Marketing                15     No
# 9      Ikram   45  57836.58    Finance                15     No
# 10       Eva   29  69930.00         IT                10    Yes
# 11     Ikram   45  45841.00  Marketing                28    Yes
# 12   Charlie   45  70395.15  Marketing                26     No
# 13     Zineb   45  59245.00         HR                35     No
# 14     David   29  64544.75  Logistics                19    Yes
# ...
